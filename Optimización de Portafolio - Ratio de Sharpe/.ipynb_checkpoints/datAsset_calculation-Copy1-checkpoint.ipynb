# %%
# Librerías a utilizar

from multiprocessing import Pool
import webbrowser
import os
import pandas as pd
import numpy as np
import itertools as it
import time as time
from scipy.optimize import minimize
import warnings
warnings.filterwarnings("ignore")

#Función que maximiza el ratio de Sharpe y entrega los pesos

def daily_portfolio_return(weights, returns):
    """
    Computes the return on a portfolio from constituent returns and weights
    weights are a numpy array or Nx1 matrix and returns are a numpy array or Nx1 matrix
    """
    return (weights.T @ returns)
    
def daily_portfolio_vol(weights, covmat):
    """
    Computes the vol of a portfolio from a covariance matrix and constituent weights
    weights are a numpy array or N x 1 maxtrix and covmat is an N x N matrix
    """
    return (weights.T @ covmat @ weights)**0.5
    
def daily_neg_sharpe(weights, riskfree_rate, er, cov):
    """
    Returns the negative of the sharpe ratio
    of the given portfolio
    """
    r = daily_portfolio_return(weights, er)
    vol = daily_portfolio_vol(weights, cov)
    return -(r - riskfree_rate)/vol

def portfolio_return(weights, returns):
        """
        Computes the return on a portfolio from constituent returns and weights
        weights are a numpy array or Nx1 matrix and returns are a numpy array or Nx1 matrix
        """
        return 252*(weights.T @ returns)
    
def portfolio_vol(weights, covmat):
    """
    Computes the vol of a portfolio from a covariance matrix and constituent weights
    weights are a numpy array or N x 1 maxtrix and covmat is an N x N matrix
    """
    return (252*(weights.T @ covmat @ weights))**0.5
    
def neg_sharpe(weights, riskfree_rate, er, cov):
    """
    Returns the negative of the sharpe ratio
    of the given portfolio
    """
    r = portfolio_return(weights, er)
    vol = portfolio_vol(weights, cov)
    return -(r - riskfree_rate)/vol

def msr(riskfree_rate, er, cov):
    """
    Returns the weights of the portfolio that gives you the maximum sharpe ratio
    given the riskfree rate and expected returns and a covariance matrix
    """
    n = er.shape[0]
    init_guess = np.repeat(1/n, n)
    bounds = np.array(((0.05, 1.0),) * n) # an N-tuple of 2-tuples!
    # construct the constraints
    weights_sum_to_1 = {'type': 'eq',
                        'fun': lambda weights: np.sum(weights) - 1
    }

    weights = minimize(neg_sharpe, init_guess,
                       args=(riskfree_rate, er, cov), method='SLSQP',
                       options={'disp': False},
                       constraints=(weights_sum_to_1,),
                       bounds=bounds)
    return weights.x

# %% [markdown]
# # Elección de portafolio datAsset Improve
#
#
# Para la optimización en la elección del portafolio ***Improve*** de **datAsset**, se escogerá el portafolio con mayor ratio de Sharpe entre todas las combinaciones posibles de portafolio de 7 acciones, que cumplan con ponderar por lo bajo **5%** cada una.
#
# Cabe destacar que nuestra regla de decisión se basará en torno al ratio de Sharpe, el cual se calcula con la siguiente fórmula:
#
# $$S=\frac{\mathbb{E}(r_P)-r_f}{\sigma_P}$$
#
# Nos remitiremos solo a las acciones que nos permitan obtener un Ratio de Sharpe positivo, por lo que eliminaremos todas las acciones cuyos retornos logarítmicos diarios promedio los dos primeros años sean menores al retorno diario del activo libre de riesgo.
#
# Escogeremos nuestros activos del **S&P100**, y en NYSE se transan aprox. 252 días al año, nuestro retorno diario para el activo libre de riesgo sería **2.7%**. En el caso de querer hacer cálculos diarios se divide por la cantidad de días transables.

# %%
# Calculo activo libre de riesgo

risk_free_asset = [0.027 , 0]
risk_free = [0.027/252 , 0]

# %% [markdown]
# Ahora que ya tenemos definido nuestro problema, debemos obtener los datos para esto el siguiente script se encarga de descargar todos los datos de Yahoo Finance para las fechas entre el **01 de Enero del 2017** y **31 de Diciembre del 2019**.

# %%
# Se descargan todos los históricos del SP&100

assets = ["AAPL", "ABBV", "ABT", "ACN", "ADBE", "AIG", "ALL", "AMGN", "AMT", 
              "AMZN", "AXP", "BA", "BAC", "BIIB", "BK", "BKNG", "BLK", "BMY", 
              "C", "CAT", "CHTR", "CL", "CMCSA", "COF", "COP", "COST", "CRM", 
              "CSCO", "CVS", "CVX", "DD", "DHR", "DIS", "DOW", "DUK", "EMR", 
              "EXC", "F", "FB", "FDX", "GD", "GE", "GILD", "GM", "GOOG", "GOOGL", 
              "GS", "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KHC", "KMI", "KO",
              "LLY", "LMT", "LOW", "MA", "MCD", "MDLZ", "MDT", "MET", "MMM", "MO", 
              "MRK", "MS", "MSFT", "NEE", "NFLX", "NKE", "NVDA", "ORCL", "OXY", 
              "PEP", "PFE", "PG", "PM", "PYPL", "QCOM", "RTX", "SBUX", "SLB", 
              "SO", "SPG", "T", "TGT", "TMO", "TXN", "UNH", "UNP", "UPS", "USB", 
              "V", "VZ", "WBA", "WFC", "WMT", "XOM"]

'''
for i in assets:
    link = "https://query1.finance.yahoo.com/v7/finance/download/{}?period1=1483228800&period2=1577750400&interval=1d&events=history".format(i)
    webbrowser.open(link)
'''
# Out:
# '\nfor i in assets:\n    link = "https://query1.finance.yahoo.com/v7/finance/download/{}?period1=1483228800&period2=1577750400&interval=1d&events=history".format(i)\n    webbrowser.open(link)\n'

# %% [markdown]
# ### Análisis de los activos
#
# Ahora analizamos que todos los activos lleven la misma cantidad de días transandose, para no tener problemas más adelante con el cálculo de los retornos.

# %%
df_shape = pd.DataFrame(index=assets, columns=["shape"])

for filename in os.listdir('data/assets'):
    file = open('data/assets/'+filename)
    df_shape.loc[os.path.basename(file.name)[:-4]]["shape"] = pd.read_csv('data/assets/'+filename).shape[0]
    
df_shape[df_shape["shape"]<753]
# Out:
#     shape
# DOW   198

# %% [markdown]
# Se elimina *Dow Inc (DOW)* por tener solo 198 días transando en el mercado. Además se leen todos los precios de los activos y se crea un dataframe con los cierres ajustados.

# %%
# Se elimina DOW y se genera un dataframe con cierres ajsutados

assets = ["AAPL", "ABBV", "ABT", "ACN", "ADBE", "AIG", "ALL", "AMGN", "AMT", 
              "AMZN", "AXP", "BA", "BAC", "BIIB", "BK", "BKNG", "BLK", "BMY", 
              "C", "CAT", "CHTR", "CL", "CMCSA", "COF", "COP", "COST", "CRM", 
              "CSCO", "CVS", "CVX", "DD", "DHR", "DIS", "DUK", "EMR", 
              "EXC", "F", "FB", "FDX", "GD", "GE", "GILD", "GM", "GOOG", "GOOGL", 
              "GS", "HD", "HON", "IBM", "INTC", "JNJ", "JPM", "KHC", "KMI", "KO",
              "LLY", "LMT", "LOW", "MA", "MCD", "MDLZ", "MDT", "MET", "MMM", "MO", 
              "MRK", "MS", "MSFT", "NEE", "NFLX", "NKE", "NVDA", "ORCL", "OXY", 
              "PEP", "PFE", "PG", "PM", "PYPL", "QCOM", "RTX", "SBUX", "SLB", 
              "SO", "SPG", "T", "TGT", "TMO", "TXN", "UNH", "UNP", "UPS", "USB", 
              "V", "VZ", "WBA", "WFC", "WMT", "XOM"]

Maestro = pd.read_csv('data/assets/AAPL.csv')[["Date"]]

for asset in assets:
    A = pd.read_csv('data/assets/'+asset+".csv")
    Maestro[asset] = A['Adj Close']

# %% [markdown]
# ### Cálculo de retornos
#
# Se calculan los retornos logaritmicos con el siguiente scripr, para esto se utiliza la fórmula
#
# $$r_t=\ln\left(\frac{p_t}{p_{t-1}}\right)$$
#
# Además creamos variables para el año el día y la fecha.

# %%
# Se calculan los retornos logarítimicos y retorno libre de riesgo

ret = Maestro.iloc[1:][assets]/Maestro.iloc[:-1][assets].values
log_ret = ret.apply(np.log)
log_ret.Date = Maestro.Date
log_ret.Date = pd.to_datetime(log_ret.Date)
log_ret[['year','month','day']] = log_ret.Date.apply(lambda x: pd.Series(x.strftime("%Y,%m,%d").split(",")))
log_ret
# Out:
#          AAPL      ABBV       ABT       ACN      ADBE       AIG       ALL  \
# 1   -0.001120  0.014002  0.007907  0.002401  0.006358  0.012968  0.002693
# 2    0.005073  0.007556  0.008601 -0.015104  0.016854 -0.005624 -0.004582
# 3    0.011087  0.000314  0.026841  0.011328  0.022315  0.018277  0.001620
# 4    0.009118  0.006563 -0.000981 -0.011241  0.002490 -0.006457 -0.014399
# 5    0.001008 -0.002183  0.013410  0.000522 -0.002859  0.012277  0.008989
# ..        ...       ...       ...       ...       ...       ...       ...
# 748  0.016187  0.010694  0.007931 -0.001280  0.004082 -0.011121 -0.006293
# 749  0.000950 -0.004442 -0.000802  0.003693  0.002095 -0.000589  0.002612
# 750  0.019646 -0.000223  0.000000  0.002077  0.004721 -0.006302  0.003860
# 751 -0.000380 -0.007038  0.001374  0.000801 -0.001239  0.008850  0.002417
# 752  0.005918 -0.007652 -0.006889 -0.007473 -0.007434 -0.001372 -0.000894
#
#          AMGN       AMT      AMZN  ...       USB         V        VZ  \
# 1    0.014098  0.001788  0.004646  ...  0.007357  0.008143 -0.001100
# 2    0.000719 -0.003485  0.030270  ... -0.016925  0.011660  0.002199
# 3    0.024536 -0.006628  0.019716  ...  0.006454  0.013717 -0.014955
# 4    0.013054 -0.002377  0.001168  ... -0.004493 -0.005611 -0.010950
# 5   -0.000504 -0.014579 -0.001281  ...  0.002933 -0.005397  0.001517
# ..        ...       ...       ...  ...       ...       ...       ...
# 748 -0.000123 -0.003387  0.003632  ... -0.003184 -0.004906 -0.010853
# 749 -0.002884  0.000485 -0.002116  ...  0.001509  0.002616 -0.001956
# 750 -0.001776  0.007931  0.043506  ...  0.008012  0.008441  0.000163
# 751 -0.001531  0.005296  0.000551  ... -0.007007  0.001215  0.003908
# 752 -0.005230 -0.001005 -0.012328  ... -0.002363 -0.008271 -0.005214
#
#           WBA       WFC       WMT       XOM  year  month  day
# 1    0.000241  0.000892  0.005809 -0.011063  2017     01   04
# 2    0.000602 -0.015643  0.002170 -0.015019  2017     01   05
# 3    0.000843 -0.002541 -0.013821 -0.000565  2017     01   06
# 4   -0.006641 -0.014641  0.006571 -0.016635  2017     01   09
# 5    0.001453  0.006981 -0.007010 -0.012835  2017     01   10
# ..        ...       ...       ...       ...   ...    ...  ...
# 748  0.003078  0.008960 -0.010530  0.004992  2019     12   23
# 749 -0.003763  0.000186  0.004025 -0.003849  2019     12   24
# 750  0.009382  0.006113  0.000084  0.001570  2019     12   26
# 751  0.002035 -0.004257  0.000586 -0.003428  2019     12   27
# 752 -0.001866 -0.005952 -0.001590 -0.005884  2019     12   30
#
# [752 rows x 102 columns]

# %% [markdown]
# Lo que haremos ahora será particionar la tabla de retornos logarítmicos en 2, una tabla para los dos primeros años que llamaremos **log_ret_f2y** y una tabla para el último año que llamaremos **log_ret_ly**.

# %%
# Se particionen los retornos logaritmicos de los dos primeros años y los del último año

log_ret_f2y = log_ret[(log_ret['year']=='2017') | (log_ret['year']=='2018')]
log_ret_ly = log_ret[(log_ret['year']=='2019')]

# %% [markdown]
# ### Regla de exclusión
#
# Ahora se eliminaran los activos con un retorno menor que el retorno del activo libre de riesgo, para disminuir el conjunto objetivo en nuestra futura optimización. Para esto calculamos los retornos promedio y desviaciones para ambas particiones, e imponemos el filtro para los activos cuyo retorno promedio para ambas particiones sea mayor al del activo libre de riesgo. Además entre las resultantes se escojerán los 25 activos con mayor rentabilidad promedio.

# %%
# Se calculan los retornos promedios y desviaciones para ambas particiones

ret_mean_f2y = log_ret_f2y.mean()
ret_std_f2y = log_ret_f2y.std()

ret_mean_ly = log_ret_ly.mean()
ret_std_ly = log_ret_ly.std()

log_ret_ly = log_ret_ly[(ret_mean_f2y[ret_mean_f2y>risk_free[0]].index) & (ret_mean_ly[ret_mean_ly>risk_free[0]].index)]

temp_assets = log_ret_ly.mean().sort_values(ascending=False)
temp_assets = np.array(temp_assets.head(28).index)[3:]
temp_assets
# Out:
# array(['AAPL', 'NVDA', 'MA', 'MSFT', 'FB', 'LMT', 'ACN', 'DHR', 'AMT',
#        'JPM', 'COST', 'BAC', 'TMO', 'ADBE', 'V', 'NEE', 'PG', 'TXN',
#        'SBUX', 'ALL', 'NKE', 'HON', 'UNP', 'DIS', 'LOW'], dtype=object)

# %% [markdown]
# Logramos reducir a 25 los activos cuyo retorno promedio diario en ambas particiones fuera mayor al activo libre de riesgo, y luego escogiendo las 25 mayores rentabilidades para el último año. Ahora queremos ver cuantos portafolios de entre 7 activos podemos construir con estos, la respuesta sería:
#
# $$N=\frac{25!}{(18)!\cdot 7!}=480700$$
#
# Tenemos cerca de **480.000** portafolios, y a cada uno de estos portafolios debemos optimizar su ponderación para obtener así el portafolio con mayor ratio de Sharpe. Es decir, debemos realizar 480.000 optimizaciones con algún metodo numérico, por lo que el computo tardaría si lo hacemos en un computador convencional, por lo que recurriremos a la nube de Google (**Google Cloud Platform**) para realizar este computo.

# %%
# Ejemplo del optimizador para escoger el óptimo de 3 activos entre 5

# filtered_assets = temp_assets
filtered_assets = ['AAPL', 'ABBV', 'ABT','ACN','UNH']
n = 3

tiempo = time.time()
max_sharpe = ["Assets","Weights","Sharpe_ratio"]
max_sharpe = ["Assets","Weights",0]

options = it.combinations(filtered_assets,n)

start = time.time()

for subset in options:

    subset = list(subset)
    
    cov = log_ret_f2y[subset].cov()
    ret = ret_mean_f2y[subset].values
    ass = ret_mean_f2y[subset].index.values
    
    if ret.shape[0]==cov.shape[0]:
        weights = msr(risk_free_asset[0],ret,cov)

        if max_sharpe[2]<-neg_sharpe(weights, risk_free_asset[0], ret, cov):
            max_sharpe[0] = subset
            max_sharpe[1] = weights
            max_sharpe[2] = -neg_sharpe(weights, risk_free_asset[0], ret, cov)
        else: pass
    else: pass

end = time.time()
print(end - start)
print("La cartera que máximiza el ratio de Sharpe es: ")
print(max_sharpe[0])
print("")
print("Los pesos respectivos son: ")
print(max_sharpe[1])
print("")
print("El ratio de Sharpe es: ")
print(max_sharpe[2])
# Out:
# 0.24701356887817383
# La cartera que máximiza el ratio de Sharpe es:
# ['ABBV', 'ABT', 'UNH']
#
# Los pesos respectivos son:
# [0.05       0.80766278 0.14233722]
#
# El ratio de Sharpe es:
# 1.6343513704636377

# %%
# Optimizador, se recomienda no ejecutar este código; es demasiado procesamiento. Se ejecutara en GCP

'''
filtered_assets = temp_assets

max_sharpe = ["Assets","Weights","Sharpe_ratio"]
max_sharpe = ["Assets","Weights",0]

k=1


for subset in it.combinations(filtered_assets,7):
    subset = list(subset)

    cov = log_ret_f2y[subset].cov()
    ret = ret_mean_f2y[subset].values
    ass = ret_mean_f2y[subset].index.values

    if ret.shape[0]==cov.shape[0]:
        weights = msr(risk_free_asset[0],ret,cov)

        if max_sharpe[2]<-neg_sharpe(weights, risk_free_asset[0], ret, cov):
            max_sharpe[0] = subset
            max_sharpe[1] = weights
            max_sharpe[2] = -neg_sharpe(weights, risk_free_asset[0], ret, cov)
        else: pass
        if k%1000==0: 
            print(k)
            print("La cartera que máximiza el ratio de Sharpe es: ")
            print(max_sharpe[0])
            print("")
            print("Los pesos respectivos son: ")
            print(max_sharpe[1])
            print("")
            print("El ratio de Sharpe es: ")
            print(max_sharpe[2])
        else: pass
        k+=1
        
print("La cartera que máximiza el ratio de Sharpe es: ")
print(max_sharpe[0])
print("")
print("Los pesos respectivos son: ")
print(max_sharpe[1])
print("")
print("El ratio de Sharpe es: ")
print(max_sharpe[2])
'''
# Out:
# 1000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'MSFT', 'AMT', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.06812564 0.05       0.12698382 0.14154465
#  0.51334588]
#
# El ratio de Sharpe es:
# 1.6566844915817573
# 2000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'MSFT', 'AMT', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.06812564 0.05       0.12698382 0.14154465
#  0.51334588]
#
# El ratio de Sharpe es:
# 1.6566844915817573
# 3000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'MSFT', 'AMT', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.06812564 0.05       0.12698382 0.14154465
#  0.51334588]
#
# El ratio de Sharpe es:
# 1.6566844915817573
# 4000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'MSFT', 'AMT', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.06812564 0.05       0.12698382 0.14154465
#  0.51334588]
#
# El ratio de Sharpe es:
# 1.6566844915817573
# 5000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'MSFT', 'AMT', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.06812564 0.05       0.12698382 0.14154465
#  0.51334588]
#
# El ratio de Sharpe es:
# 1.6566844915817573
# 6000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 7000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 8000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 9000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 10000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 11000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 12000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 13000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 14000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 15000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 16000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 17000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 18000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 19000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 20000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 21000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 22000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 23000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 24000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 25000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 26000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 27000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 28000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 29000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 30000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 31000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 32000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 33000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 34000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 35000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'NVDA', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.05       0.07401753 0.12066368 0.05267902 0.14115788
#  0.51148189]
#
# El ratio de Sharpe es:
# 1.6784250886998842
# 36000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'ACN', 'AMT', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08143898 0.05       0.05       0.12486732 0.14848943
#  0.49520428]
#
# El ratio de Sharpe es:
# 1.7126986027341202
# 37000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'DHR', 'AMT', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.09401596 0.05       0.05       0.12446492 0.13864946
#  0.49286966]
#
# El ratio de Sharpe es:
# 1.7351779697835956
# 38000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 39000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 40000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 41000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 42000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 43000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 44000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 45000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 46000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 47000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 48000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 49000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 50000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 51000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 52000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 53000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 54000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'MSFT', 'AMT', 'TMO', 'ADBE', 'NEE']
#
# Los pesos respectivos son:
# [0.05       0.08701737 0.05       0.12039134 0.06149228 0.13348358
#  0.49761544]
#
# El ratio de Sharpe es:
# 1.7616461208184198
# 55000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 56000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 57000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 58000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 59000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 60000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 61000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 62000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 63000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 64000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 65000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 66000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 67000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 68000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 69000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 70000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 71000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 72000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 73000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 74000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 75000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 76000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 77000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 78000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 79000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 80000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 81000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 82000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 83000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 84000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 85000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 86000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 87000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 88000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 89000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 90000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 91000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 92000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 93000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 94000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 95000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 96000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 97000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 98000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 99000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 100000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 101000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 102000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 103000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 104000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 105000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 106000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 107000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 108000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 109000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 110000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 111000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 112000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 113000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 114000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 115000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 116000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 117000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 118000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 119000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 120000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 121000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 122000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 123000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 124000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 125000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 126000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 127000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 128000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 129000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 130000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 131000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 132000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 133000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 134000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 135000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 136000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 137000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 138000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 139000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 140000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 141000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 142000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 143000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 144000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 145000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 146000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 147000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 148000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 149000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 150000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 151000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 152000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 153000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 154000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 155000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 156000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 157000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 158000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 159000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 160000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 161000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 162000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 163000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 164000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 165000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 166000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 167000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 168000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 169000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 170000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 171000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 172000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 173000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 174000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 175000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 176000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 177000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 178000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 179000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 180000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 181000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 182000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 183000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 184000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 185000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.05       0.09378621 0.11528259 0.05834278 0.13818436 0.49440405
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.7824980277017026
# 186000
# La cartera que máximiza el ratio de Sharpe es:
# ['AAPL', 'MA', 'AMT', 'TMO', 'ADBE', 'NEE', 'UNP']
#
# ...
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 420000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 421000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 422000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 423000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 424000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 425000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 426000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 427000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 428000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 429000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 430000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 431000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 432000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 433000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 434000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 435000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 436000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 437000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 438000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 439000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 440000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 441000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 442000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 443000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 444000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 445000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 446000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 447000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 448000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 449000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 450000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 451000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 452000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 453000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 454000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 455000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 456000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 457000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 458000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 459000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 460000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 461000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 462000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 463000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 464000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 465000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 466000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 467000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 468000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 469000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 470000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 471000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 472000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 473000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 474000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 475000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 476000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 477000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 478000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 479000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# 480000
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897 0.11786622 0.06310098 0.13417054 0.05       0.49719328
#  0.05      ]
#
# El ratio de Sharpe es:
# 1.815901773399938

# %%
print("La cartera que máximiza el ratio de Sharpe es: ")
print(['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP'])
print("")
print("Los pesos respectivos son: ")
print([0.08766897,0.11786622,0.06310098,0.13417054,0.05,0.49719328,0.05])
print("")
print("El ratio de Sharpe es: ")
print(1.815901773399938)
# Out:
# La cartera que máximiza el ratio de Sharpe es:
# ['MA', 'AMT', 'TMO', 'ADBE', 'V', 'NEE', 'UNP']
#
# Los pesos respectivos son:
# [0.08766897, 0.11786622, 0.06310098, 0.13417054, 0.05, 0.49719328, 0.05]
#
# El ratio de Sharpe es:
# 1.815901773399938
