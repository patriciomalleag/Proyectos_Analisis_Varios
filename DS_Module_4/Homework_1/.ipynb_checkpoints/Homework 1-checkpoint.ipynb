# %% [markdown]
# # Tarea 1

# %% [markdown]
# ### Primera parte
#
# Utilizar la base de datos OnlineRetail.csv para responder lo siguiente:
#
#     1. Graficar la cantidad de ordenes (Invoice) por cada día de la semana. ¿Qué día se producen la mayor cantidad de ordenes y cuando la menor?
#     2. ¿Cuales son los 5 países que más gastan en promedio? Graficar y tabla.
#     3. Hay items que la empresa entrega de regalo, ¿Cuantos se regalaron?. Indicar cantidad por mes. (usar supuesto)

# %%
#Librerías

import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
# Lectura del dataframe

df_retail = pd.read_csv("https://raw.githubusercontent.com/patriciomalleag/Proyectos_Analisis_Varios/master/DS_Module_4/Homework_1/OnlineRetail.csv", sep=",", encoding = "ISO-8859-1")

# %%
# Dimensión del dataframe

df_retail.shape
# Out:
# (541909, 8)

# %%
# Primeros 5 elementos

df_retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Información de los datos

df_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ---
#
# Viendo los datos y los resultados para los tipos de datos, el primer detalle que encontramos a priori es el tipo de dato que tiene el campo *InvoiceDate*, el cual debería ser del tipo datetime, no obstante por defecto pandas lo reconocio como object. Debemos hacer una transformación para este campo.
#
# Otro detalle es que tanto el campo *Description* como el campo *CustomerID* tienen algunos nulos. Vale la pena más adelante analizar por qué ocurre esto.
#
# ---

# %%
# Estadísticos descriptivos

df_retail.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ---
#
# Tanto el campo *Quantity* como el campo *UnitPrice* tienen valores negativos. Realicemos un análisis rápido de lo que ocurre.
#
# ---

# %%
# UnitPrice menor que 0

df_uprice_less_0 = df_retail[(df_retail["UnitPrice"]<0)].sort_values(by=['UnitPrice'])
df_uprice_less_0
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# ---
#
# Los registros negativos en el campo *UnitPrice* corresponden al parecer a ajustes de crédito por lo que no los consideraremos en el análisis.
#
# ---

# %%
# Quantity menor que 0

df_qty_less_0 = df_retail[(df_retail["Quantity"]<0)]
df_qty_less_0
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141      12/1/2010 9:41      27.50     14527.0  United Kingdom
# 154      12/1/2010 9:49       4.65     15311.0  United Kingdom
# 235     12/1/2010 10:24       1.65     17548.0  United Kingdom
# 236     12/1/2010 10:24       0.29     17548.0  United Kingdom
# 237     12/1/2010 10:24       0.29     17548.0  United Kingdom
# ...                 ...        ...         ...             ...
# 540449   12/9/2011 9:57       0.83     14397.0  United Kingdom
# 541541  12/9/2011 10:28     224.69     15498.0  United Kingdom
# 541715  12/9/2011 11:57      10.95     15311.0  United Kingdom
# 541716  12/9/2011 11:58       1.25     17315.0  United Kingdom
# 541717  12/9/2011 11:58       1.25     17315.0  United Kingdom
#
# [10624 rows x 8 columns]

# %% [markdown]
# ---
#
# Los registros negativos en el campo *Quantity* corresponden al parecer a devoluciones, descuentos u otros. No obstante ya que en la pregunta 3 se nos indica que la tienda regala ciertos objetos, revisaremos las descripciones de los que tienen *UnitPrice* 0 para este dataframe.
#
# ---

# %%
# Lista de Quantity<0 y UnitPrice==0

list(df_qty_less_0[df_qty_less_0["UnitPrice"]==0].Description.drop_duplicates())
# Out:
# [nan,
#  '?',
#  'check',
#  'damages',
#  'faulty',
#  'Dotcom sales',
#  'reverse 21/5/10 adjustment',
#  'mouldy, thrown away.',
#  'counted',
#  'Given away',
#  'Dotcom',
#  'label mix up',
#  'samples/damages',
#  'thrown away',
#  'incorrectly made-thrown away.',
#  'showroom',
#  'MIA',
#  'Dotcom set',
#  'wrongly sold as sets',
#  'Amazon sold sets',
#  'dotcom sold sets',
#  'wrongly sold sets',
#  '? sold as sets?',
#  '?sold as sets?',
#  'Thrown away.',
#  'damages/display',
#  'damaged stock',
#  'broken',
#  'throw away',
#  'wrong barcode (22467)',
#  'wrong barcode',
#  'barcode problem',
#  '?lost',
#  "thrown away-can't sell.",
#  "thrown away-can't sell",
#  'damages?',
#  're dotcom quick fix.',
#  "Dotcom sold in 6's",
#  'sold in set?',
#  'cracked',
#  'sold as 22467',
#  'Damaged',
#  'mystery! Only ever imported 1800',
#  'MERCHANT CHANDLER CREDIT ERROR, STO',
#  'POSSIBLE DAMAGES OR LOST?',
#  'damaged',
#  'DAMAGED',
#  'Display',
#  'Missing',
#  'wrong code?',
#  'wrong code',
#  'adjust',
#  'crushed',
#  'damages/showroom etc',
#  'samples',
#  'damages/credits from ASOS.',
#  'Not rcvd in 10/11/2010 delivery',
#  'Thrown away-rusty',
#  'sold as set/6 by dotcom',
#  'wet/rusty',
#  'damages/dotcom?',
#  'smashed',
#  'reverse previous adjustment',
#  'incorrectly credited C550456 see 47',
#  'wet damaged',
#  'Water damaged',
#  'missing',
#  'sold as set on dotcom',
#  'sold as set on dotcom and amazon',
#  'water damage',
#  'sold as set by dotcom',
#  'Printing smudges/thrown away',
#  'printing smudges/thrown away',
#  'found some more on shelf',
#  'Show Samples',
#  'mix up with c',
#  'mouldy, unsaleable.',
#  'wrongly marked. 23343 in box',
#  'stock creditted wrongly',
#  'ebay',
#  'incorrectly put back into stock',
#  'Damages/samples',
#  'Sold as 1 on dotcom',
#  'taig adjust no stock',
#  'code mix up? 84930',
#  '?display?',
#  'sold as 1',
#  '?missing',
#  'crushed ctn',
#  'Crushed',
#  'temp adjustment',
#  '??',
#  'test',
#  'OOPS ! adjustment',
#  'Dagamed',
#  'historic computer difference?....se',
#  'Incorrect stock entry.',
#  'incorrect stock entry.',
#  'wrongly coded-23343',
#  'stock check',
#  'crushed boxes',
#  'WET/MOULDY',
#  "can't find",
#  'mouldy',
#  'Wet pallet-thrown away',
#  'adjustment',
#  '20713 wrongly marked',
#  're-adjustment',
#  'Breakages',
#  '20713',
#  'wrongly coded 20713',
#  'Damages',
#  'CHECK',
#  'Unsaleable, destroyed.',
#  'dotcom sales',
#  'damages wax',
#  'water damaged',
#  'Wrongly mrked had 85123a in box',
#  'wrongly marked carton 22804',
#  'missing?',
#  'wet rusty',
#  '???lost',
#  'sold with wrong barcode',
#  'rusty thrown away',
#  'rusty throw away',
#  'dotcom',
#  '?? missing',
#  'wet pallet',
#  '????missing',
#  '???missing',
#  'lost in space',
#  'wet?',
#  'lost??',
#  '???',
#  'wet',
#  'wet boxes',
#  '????damages????',
#  'mixed up',
#  'lost']

# %% [markdown]
# ---
#
# Al parecer todos son productos averiados, por lo que podemos también descartar este subconjunto para nuestro análisis. Ahora revisaremos los registros con *UnitPrice* igual a 0 y *Quantity* positivo. Eliminaremos los Description NaN para facilidad de análisis,
#
# ---

# %%
# Quantity>0 y UnitPrice==0

df_uprice_0 = df_retail[ (df_retail["Quantity"]>0) & (df_retail["UnitPrice"]==0) ]
list(df_uprice_0[df_uprice_0["Description"].notna()].Description.drop_duplicates())
# Out:
# ['amazon',
#  'ROUND CAKE TIN VINTAGE GREEN',
#  'CREAM SWEETHEART LETTER RACK',
#  'ZINC WILLIE WINKIE  CANDLE STICK',
#  'BOX OF 24 COCKTAIL PARASOLS',
#  'DOORMAT ENGLISH ROSE ',
#  'DOORMAT 3 SMILEY CATS',
#  'GREEN REGENCY TEACUP AND SAUCER',
#  'FRENCH BLUE METAL DOOR SIGN 7',
#  'FRENCH BLUE METAL DOOR SIGN 5',
#  'FRENCH BLUE METAL DOOR SIGN 6',
#  'FRENCH BLUE METAL DOOR SIGN 4',
#  'FRENCH BLUE METAL DOOR SIGN No',
#  'FRENCH BLUE METAL DOOR SIGN 8',
#  'FRENCH BLUE METAL DOOR SIGN 1',
#  'RED KITCHEN SCALES',
#  'IVORY KITCHEN SCALES',
#  'SET OF 6 SOLDIER SKITTLES',
#  'CHILDS GARDEN TROWEL BLUE ',
#  'CHILDRENS GARDEN GLOVES BLUE',
#  'PICNIC BASKET WICKER SMALL',
#  'PICNIC BASKET WICKER LARGE',
#  'EMPIRE UNION JACK TV DINNER TRAY',
#  'TV DINNER TRAY VINTAGE PAISLEY',
#  'SPACEBOY TV DINNER TRAY',
#  'TV DINNER TRAY DOLLY GIRL',
#  'CHILDS GARDEN SPADE BLUE',
#  'CHILDS GARDEN RAKE BLUE',
#  'WATERING CAN PINK BUNNY',
#  'ENAMEL FIRE BUCKET CREAM',
#  'ENAMEL FLOWER JUG CREAM',
#  'AIRLINE BAG VINTAGE JET SET WHITE',
#  'AIRLINE BAG VINTAGE JET SET BROWN',
#  'AIRLINE BAG VINTAGE WORLD CHAMPION ',
#  'AIRLINE BAG VINTAGE TOKYO 78',
#  '4 TRADITIONAL SPINNING TOPS',
#  'FULL ENGLISH BREAKFAST PLATE',
#  'CHILDRENS APRON SPACEBOY DESIGN',
#  'DOORMAT AIRMAIL ',
#  'GLASS JAR DIGESTIVE BISCUITS',
#  'GLASS JAR PEACOCK BATH SALTS',
#  'GLASS JAR ENGLISH CONFECTIONERY',
#  'GLASS JAR DAISY FRESH COTTON WOOL',
#  'GLASS JAR KINGS CHOICE',
#  'LUNCH BOX WITH CUTLERY FAIRY CAKES ',
#  'ILLUSTRATED CAT BOWL ',
#  'ROUND SNACK BOXES SET OF 4 SKULLS',
#  'OWL DOORSTOP',
#  'MILK PAN PINK POLKADOT',
#  'HOLIDAY FUN LUDO',
#  'VINTAGE SNAKES & LADDERS',
#  'TRADITIONAL WOODEN SKIPPING ROPE',
#  'STRAWBERRY LUNCH BOX WITH CUTLERY',
#  'RED RETROSPOT SUGAR JAM BOWL',
#  'LUNCH BAG WOODLAND',
#  'BLUE POLKADOT LUGGAGE TAG ',
#  'BLUE POLKADOT PASSPORT COVER',
#  'STRAWBERRY CERAMIC TRINKET BOX',
#  'PACK OF 6 BIRDY GIFT TAGS',
#  'amazon sales',
#  'WHITE SKULL HOT WATER BOTTLE ',
#  'CHOCOLATE HOT WATER BOTTLE',
#  'CHARLOTTE BAG PINK POLKADOT',
#  'ADVENT CALENDAR GINGHAM SACK',
#  '?',
#  'Found',
#  'REGENCY CAKESTAND 3 TIER',
#  'HOT WATER BOTTLE TEA AND SYMPATHY',
#  'TRAVEL SEWING KIT',
#  'SET/20 RED RETROSPOT PAPER NAPKINS ',
#  'FAWN BLUE HOT WATER BOTTLE',
#  'GROW YOUR OWN PLANT IN A CAN ',
#  'RED RETROSPOT CHILDRENS UMBRELLA',
#  'RED RETROSPOT CHARLOTTE BAG',
#  'PORCELAIN BUTTERFLY OIL BURNER',
#  'WHITE HANGING HEART T-LIGHT HOLDER',
#  'SET OF 16 VINTAGE BLACK CUTLERY',
#  'TEATIME FUNKY FLOWER BACKPACK FOR 2',
#  'CHILDS GARDEN BRUSH BLUE',
#  'CHILLI LIGHTS',
#  'DOORMAT HEARTS',
#  'RETRO "TEA FOR ONE" ',
#  'BISCUIT TIN VINTAGE GREEN',
#  'BISCUIT TIN VINTAGE RED',
#  'DOORMAT HOME SWEET HOME BLUE ',
#  'JUMBO BAG RED RETROSPOT',
#  'FRENCH BLUE METAL DOOR SIGN 0',
#  'FRENCH BLUE METAL DOOR SIGN 9',
#  'FRENCH BLUE METAL DOOR SIGN 3',
#  'FRENCH BLUE METAL DOOR SIGN 2',
#  'RECIPE BOX PANTRY YELLOW DESIGN',
#  'RECIPE BOX BLUE SKETCHBOOK DESIGN',
#  'CERAMIC PIRATE CHEST MONEY BANK',
#  'CERAMIC LOVE HEART MONEY BANK',
#  'BLACK KITCHEN SCALES',
#  'WHEELBARROW FOR CHILDREN ',
#  'CHILDRENS GARDEN GLOVES PINK',
#  'DOORSTOP RACING CAR DESIGN',
#  'SKULL DESIGN TV DINNER TRAY',
#  'WATERING CAN BLUE ELEPHANT',
#  'ENAMEL WASH BOWL CREAM',
#  'AIRLINE BAG VINTAGE JET SET RED',
#  'KINGS CHOICE BISCUIT TIN',
#  'RED RETROSPOT TEA CUP AND SAUCER ',
#  'VINTAGE HEADS AND TAILS CARD GAME ',
#  'BINGO SET',
#  'RED RETROSPOT BUTTER DISH',
#  'VICTORIAN SEWING BOX LARGE',
#  'WOODLAND CHARLOTTE BAG',
#  'PAPER BUNTING RETROSPOT',
#  'PLASTERS IN TIN SKULLS',
#  'found',
#  'BLUE SPOT CERAMIC DRAWER KNOB',
#  'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#  'ORGANISER WOOD ANTIQUE WHITE ',
#  'FAIRY CAKES NOTEBOOK A6 SIZE',
#  'MINT KITCHEN SCALES',
#  'SEASIDE FLYING DISC',
#  'HEART OF WICKER LARGE',
#  'DOORMAT RESPECTABLE HOUSE',
#  'GLASS JAR MARMALADE ',
#  'COFFEE MUG DOG + BALL DESIGN',
#  'PINK DOUGHNUT TRINKET POT ',
#  'DOORMAT RED RETROSPOT',
#  'LUNCH BAG SUKI DESIGN ',
#  'JUMBO BAG STRAWBERRY',
#  'KEY FOB , GARAGE DESIGN',
#  'ROSES REGENCY TEACUP AND SAUCER ',
#  'PINK REGENCY TEACUP AND SAUCER',
#  'DOORMAT MERRY CHRISTMAS RED ',
#  'STRAWBERRY FAIRY CAKE TEAPOT',
#  'Adjustment',
#  'POLYESTER FILLER PAD 40x40cm',
#  'POLYESTER FILLER PAD 45x45cm',
#  'wrongly sold (22719) barcode',
#  'DOORMAT WELCOME TO OUR HOME',
#  'BOX OF VINTAGE JIGSAW BLOCKS ',
#  'CHILDS GARDEN TROWEL PINK',
#  'ENAMEL WATERING CAN CREAM',
#  'CIRCUS PARADE LUNCH BOX ',
#  'CERAMIC STRAWBERRY MONEY BOX',
#  'CERAMIC BOWL WITH LOVE HEART DESIGN',
#  'rcvd be air temp fix for dotcom sit',
#  'MINI CAKE STAND  HANGING STRAWBERY',
#  'HEART GARLAND RUSTIC PADDED',
#  'CHICK GREY HOT WATER BOTTLE',
#  'CHILDS BREAKFAST SET CIRCUS PARADE',
#  'did  a credit  and did not tick ret',
#  'adjustment',
#  'returned',
#  'mailout ',
#  'mailout',
#  'BLACK MINI TAPE MEASURE ',
#  'BAKING SET SPACEBOY DESIGN',
#  'ASSTD MULTICOLOUR CIRCLES MUG',
#  'SET OF 20 KIDS COOKIE CUTTERS',
#  'BOX OF 6 ASSORTED COLOUR TEASPOONS',
#  'DOTCOM POSTAGE',
#  'PARTY BUNTING',
#  'on cargo order',
#  'CERAMIC STRAWBERRY CAKE MONEY BANK',
#  'CERAMIC CHERRY CAKE MONEY BANK',
#  'CERAMIC HEART FAIRY CAKE MONEY BANK',
#  'PIGGY BANK RETROSPOT ',
#  'CHILDS GARDEN BRUSH PINK',
#  'CHILDS GARDEN SPADE PINK',
#  'DOORMAT NEIGHBOURHOOD WITCH ',
#  'COFFEE MUG CAT + BIRD DESIGN',
#  'MILK PAN RED RETROSPOT',
#  'WOODEN BOX OF DOMINOES',
#  'ENAMEL COLANDER CREAM',
#  'FRYING PAN BLUE POLKADOT',
#  'UNION STRIPE WITH FRINGE  HAMMOCK',
#  'JUMBO BAG TOYS ',
#  'CHILDS GARDEN FORK PINK',
#  'CHILDS GARDEN FORK BLUE ',
#  'incorrectly credited C550456 see 47',
#  'to push order througha s stock was ',
#  'FOUND',
#  'JUMBO BAG SPACEBOY DESIGN',
#  'TOY TIDY SPACEBOY  ',
#  'TRAVEL CARD WALLET DOTCOMGIFTSHOP',
#  'PACK OF 12 LONDON TISSUES ',
#  'SPOTTY BUNTING',
#  'came coded as 20713',
#  'alan hodge cant mamage this section',
#  'VINTAGE LEAF MAGNETIC NOTEPAD',
#  'dotcom',
#  'FBA',
#  ' OVAL WALL MIRROR DIAMANTE ',
#  'JAM MAKING SET WITH JARS',
#  'Manual',
#  'SET OF 6 NATIVITY MAGNETS ',
#  'PARTY METAL SIGN ',
#  'GARAGE KEY FOB',
#  'KEY FOB , SHED',
#  'KEY FOB , BACK DOOR ',
#  'DINOSAUR LUNCH BOX WITH CUTLERY',
#  'TOADSTOOL MONEY BOX',
#  'SET OF 2 CERAMIC PAINTED HEARTS ',
#  'SET OF 2 CERAMIC CHRISTMAS REINDEER',
#  '36 FOIL STAR CAKE CASES ',
#  'POLKADOT RAIN HAT ',
#  'test',
#  'taig adjust',
#  'allocate stock for dotcom orders ta',
#  'add stock to allocate online orders',
#  'for online retail orders',
#  'Amazon',
#  'found box',
#  'damaged',
#  'Found in w/hse',
#  'website fixed',
#  'PADS TO MATCH ALL CUSHIONS',
#  'Lighthouse Trading zero invc incorr',
#  'michel oops',
#  'GLASS CLOCHE SMALL',
#  'wrongly coded 20713',
#  'Had been put aside.',
#  'Sale error',
#  'Amazon Adjustment',
#  'wrongly marked 23343',
#  'Marked as 23343',
#  'PASTEL COLOUR HONEYCOMB FAN',
#  'wrongly coded 23343',
#  'Found by jackie',
#  'check',
#  'wrongly marked',
#  'had been put aside',
#  'BISCUIT TIN VINTAGE CHRISTMAS',
#  'CHRISTMAS PUDDING TRINKET POT ',
#  "CHILDREN'S APRON DOLLY GIRL ",
#  'MINI LIGHTS WOODLAND MUSHROOMS',
#  'SET OF 9 BLACK SKULL BALLOONS',
#  'PAPER BUNTING VINTAGE PAISLEY',
#  'amazon adjust',
#  'dotcomstock',
#  'John Lewis',
#  'HANGING METAL HEART LANTERN',
#  'SET OF 2 TRAYS HOME SWEET HOME',
#  'dotcom adjust',
#  'check?',
#  'AMAZON',
#  'ASSTD DESIGN 3D PAPER STICKERS',
#  'FRIDGE MAGNETS LES ENFANTS ASSORTED',
#  'CLASSIC GLASS COOKIE JAR']

# %% [markdown]
# ---
#
# Acá nuestro primer gran supuesto, es que todos los productos que tienen *UnitPrice* igual a 0, *Quantity* positiva y que sea lógicamente un producto, son regalos de la tienda. Para transformar esto a código, y luego de ver las descripciones, solo nos quedaremos con los registros que tengan *Description* en mayúsculas (Salvo AMAZON y DOTCOM POSTAGE). Esto último es nuestro segundo supuesto, que solo nos quedaremos con los registros con *Description* en mayúsculas.
#
# ---

# %%
df_gift = df_uprice_0[(df_uprice_0["Description"].str.isupper()==True) & (df_uprice_0["Description"]!="AMAZON") & (df_uprice_0["Description"]!="DOTCOM POSTAGE")]

# %%
df_gift
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 9302      537197     22841         ROUND CAKE TIN VINTAGE GREEN         1
# 14335     537534     85064         CREAM SWEETHEART LETTER RACK         1
# 14336     537534     84832     ZINC WILLIE WINKIE  CANDLE STICK         1
# 14337     537534     84692          BOX OF 24 COCKTAIL PARASOLS         2
# 14338     537534     48184                DOORMAT ENGLISH ROSE          3
# ...          ...       ...                                  ...       ...
# 479079    577129     22464          HANGING METAL HEART LANTERN         4
# 480649    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 521408    580366     22923  FRIDGE MAGNETS LES ENFANTS ASSORTED         6
# 521417    580366     23169             CLASSIC GLASS COOKIE JAR         6
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 9302     12/5/2010 14:02        0.0     12647.0         Germany
# 14335    12/7/2010 11:48        0.0         NaN  United Kingdom
# 14336    12/7/2010 11:48        0.0         NaN  United Kingdom
# 14337    12/7/2010 11:48        0.0         NaN  United Kingdom
# 14338    12/7/2010 11:48        0.0         NaN  United Kingdom
# ...                  ...        ...         ...             ...
# 479079  11/17/2011 19:52        0.0     15602.0  United Kingdom
# 480649  11/18/2011 13:23        0.0     12444.0          Norway
# 502122  11/25/2011 15:57        0.0     13256.0  United Kingdom
# 521408   12/2/2011 16:38        0.0         NaN  United Kingdom
# 521417   12/2/2011 16:38        0.0         NaN  United Kingdom
#
# [399 rows x 8 columns]

# %%
# Dataframe de análisis

df_retail_dmt = df_retail[ (df_retail["UnitPrice"]>0) & (df_retail["Quantity"]>0) & (df_retail["Description"].str.isupper()==True) ]
df_retail_dmt.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  528051.000000  528051.000000  396228.000000
# mean       10.517503       3.752838   15293.581524
# std       155.673014      27.861531    1713.126203
# min         1.000000       0.001000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15157.000000
# 75%        10.000000       4.130000   16795.000000
# max     80995.000000   13541.330000   18287.000000

# %%
# Orden por precio

df_retail_dmt.sort_values(by=["UnitPrice"])
# Out:
#        InvoiceNo  StockCode                 Description  Quantity  \
# 359871    568200       PADS  PADS TO MATCH ALL CUSHIONS         1
# 279045    561226       PADS  PADS TO MATCH ALL CUSHIONS         1
# 157195    550193       PADS  PADS TO MATCH ALL CUSHIONS         1
# 326771    565593      16045  POPART WOODEN PENCILS ASST       100
# 506043    579124      16045  POPART WOODEN PENCILS ASST       100
# ...          ...        ...                         ...       ...
# 524892    580610        DOT              DOTCOM POSTAGE         1
# 493020    578149        DOT              DOTCOM POSTAGE         1
# 297723    562955        DOT              DOTCOM POSTAGE         1
# 173382    551697       POST                     POSTAGE         1
# 15017     537632  AMAZONFEE                  AMAZON FEE         1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 359871   9/25/2011 14:58      0.001     16198.0  United Kingdom
# 279045   7/26/2011 10:13      0.001     15618.0  United Kingdom
# 157195    4/15/2011 9:27      0.001     13952.0  United Kingdom
# 326771    9/5/2011 14:07      0.040     17612.0  United Kingdom
# 506043  11/28/2011 12:14      0.040     15721.0  United Kingdom
# ...                  ...        ...         ...             ...
# 524892   12/5/2011 11:48   2196.670         NaN  United Kingdom
# 493020  11/23/2011 11:11   2275.540         NaN  United Kingdom
# 297723   8/11/2011 10:14   4505.170         NaN  United Kingdom
# 173382    5/3/2011 13:46   8142.750     16029.0  United Kingdom
# 15017    12/7/2010 15:08  13541.330         NaN  United Kingdom
#
# [528051 rows x 8 columns]

# %% [markdown]
# ---
#
# Si eliminamos el AMAZON FEE y los POSTAGE nos queda lo siguiente
#
# ---

# %%
df_retail_dmt_corr = df_retail_dmt[ (df_retail_dmt["StockCode"]!="AMAZONFEE") & (df_retail_dmt["StockCode"]!="POST") & (df_retail_dmt["StockCode"]!="DOT") ]
df_retail_dmt_corr.sort_values(by=["UnitPrice"])
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 359871    568200      PADS      PADS TO MATCH ALL CUSHIONS         1
# 157195    550193      PADS      PADS TO MATCH ALL CUSHIONS         1
# 279045    561226      PADS      PADS TO MATCH ALL CUSHIONS         1
# 263241    559979     16045      POPART WOODEN PENCILS ASST       100
# 523461    580513     16045      POPART WOODEN PENCILS ASST       100
# ...          ...       ...                             ...       ...
# 133994    547814     22656    VINTAGE BLUE KITCHEN CABINET         1
# 171178    551393     22656    VINTAGE BLUE KITCHEN CABINET         1
# 32484     539080     22655     VINTAGE RED KITCHEN CABINET         1
# 222680    556444     22502  PICNIC BASKET WICKER 60 PIECES        60
# 222682    556446     22502  PICNIC BASKET WICKER 60 PIECES         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 359871  9/25/2011 14:58      0.001     16198.0  United Kingdom
# 157195   4/15/2011 9:27      0.001     13952.0  United Kingdom
# 279045  7/26/2011 10:13      0.001     15618.0  United Kingdom
# 263241  7/14/2011 11:20      0.040     14862.0  United Kingdom
# 523461  12/4/2011 13:59      0.040     14456.0  United Kingdom
# ...                 ...        ...         ...             ...
# 133994  3/25/2011 14:19    295.000     13452.0  United Kingdom
# 171178  4/28/2011 12:22    295.000     14973.0  United Kingdom
# 32484   12/16/2010 8:41    295.000     16607.0  United Kingdom
# 222680  6/10/2011 15:28    649.500     15098.0  United Kingdom
# 222682  6/10/2011 15:33    649.500     15098.0  United Kingdom
#
# [526217 rows x 8 columns]

# %% [markdown]
# ---
#
# Con esto completamos nuestra limpieza y tenemos nuestros dos dataframes para el análisis que son:
#
#     - df_retail_dmt_corr
#     - df_gift
#
# ---

# %%
# Nueva columna CorrectedDatetime, OnlyDate, WeekDay y WeekDayNumber para ambos dataframes

df_retail_dmt_corr["CorrectedDatetime"] = pd.to_datetime(df_retail_dmt_corr["InvoiceDate"])
df_retail_dmt_corr["OnlyDate"] = pd.to_datetime(df_retail_dmt_corr["InvoiceDate"]).dt.date
df_retail_dmt_corr["WeekDay"] = df_retail_dmt_corr["CorrectedDatetime"].dt.day_name()
df_retail_dmt_corr["WeekDayNumber"] = df_retail_dmt_corr["CorrectedDatetime"].dt.weekday
df_gift["CorrectedDatetime"] = pd.to_datetime(df_gift["InvoiceDate"])
df_gift["OnlyDate"] = pd.to_datetime(df_gift["InvoiceDate"]).dt.date
df_gift["WeekDay"] = df_gift["CorrectedDatetime"].dt.day_name()
df_gift["WeekDayNumber"] = df_gift["CorrectedDatetime"].dt.weekday

# %%
# Agrupamos por día de la semana y contamos el promedio de ordenes

grp_df_temp = df_retail_dmt_corr.groupby(
            ["WeekDayNumber","OnlyDate","WeekDay"], as_index=False).agg(
            count_unique = pd.NamedAgg('InvoiceNo','nunique')).groupby(
            ["WeekDayNumber","WeekDay"],as_index=False).agg(
            InvoiceMean = pd.NamedAgg('count_unique','mean'))

# %%
fig, ax = plt.subplots()

bars = ax.bar(
    x=grp_df_temp["WeekDay"],
    height=grp_df_temp["InvoiceMean"]
)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

bar_color = bars[0].get_facecolor()
for bar in bars:
  ax.text(
      bar.get_x() + bar.get_width() / 2,
      bar.get_height() + 0.3,
      round(bar.get_height(), 1),
      horizontalalignment='center',
      color=bar_color,
      weight='bold'
  )

ax.set_xlabel('Día de la semana', labelpad=15, color='#333333')
ax.set_ylabel('Número de compras', labelpad=15, color='#333333')
ax.set_title('Compras promedio por día de la semana', pad=15, color='#333333',
             weight='bold')

fig.set_figheight(6)
fig.set_figwidth(8)
fig.tight_layout()

# %% [markdown]
# ---
#
# Del gráfico podemos inferir que en promedio, la mayor cantidad de compras se realizan los días Jueves y la menor cantidad los días Domingos. Cabe destacar que posterior a la limpieza, no tenemos compras el día sabado. Veamos en el dataset original que registros aparecían este día.
#
# ---

# %%
# Registros día sabado dataset pre-limpieza
df_retail["CorrectedDatetime"] = pd.to_datetime(df_retail["InvoiceDate"])
df_retail["WeekDay"] = df_retail["CorrectedDatetime"].dt.day_name()
df_retail.WeekDay.drop_duplicates()
# Out:
# 0        Wednesday
# 3108      Thursday
# 5217        Friday
# 7419        Sunday
# 10144       Monday
# 14022      Tuesday
# Name: WeekDay, dtype: object

# %% [markdown]
# ---
#
# Al parecer no habían registros los días Sábados desde el inicio, por lo que podemos suponer que la tienda no opera los días Sábados.
#
# ---
#
# Veamos ahora los 5 países que más gastan en promedio, para esto haremos 3 análisis:
#  - Promedio por registro.
#  - Promedio por Invoice.
#  - Promedio por día.
#
# ---

# %%
# Creación de columna pagado por registro

df_retail_dmt_corr["Paid"] = df_retail_dmt_corr["Quantity"] * df_retail_dmt_corr["UnitPrice"]

# %%
# Promedio por registro

df_retail_mean_row = df_retail_dmt_corr.groupby(["Country"], as_index = False).agg(
                            PaidMean = pd.NamedAgg("Paid","mean")
                        ).sort_values(by=['PaidMean'], ascending=False)
df_retail_mean_row.head(5)
# Out:
#         Country    PaidMean
# 24  Netherlands  122.260698
# 0     Australia  116.995182
# 20        Japan  116.561900
# 32       Sweden   86.363129
# 9       Denmark   49.688907

# %%
fig, ax = plt.subplots()

bars = ax.bar(
    x=df_retail_mean_row.head(5)["Country"],
    height=df_retail_mean_row.head(5)["PaidMean"]
)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

bar_color = bars[0].get_facecolor()
for bar in bars:
  ax.text(
      bar.get_x() + bar.get_width() / 2,
      bar.get_height() + 0.3,
      round(bar.get_height(), 1),
      horizontalalignment='center',
      color=bar_color,
      weight='bold'
  )

ax.set_xlabel('Países', labelpad=15, color='#333333')
ax.set_ylabel('Gasto', labelpad=15, color='#333333')
ax.set_title('Gasto promedio por registro', pad=15, color='#333333',
             weight='bold')

fig.set_figheight(6)
fig.set_figwidth(8)
fig.tight_layout()

# %% [markdown]
# ---
#
# Al hacer un análisis por registro, podemos darnos cuenta que los Holandeses son los que mas gastan por cada item que compran, seguidos por los Australianos, luego Japoneses, terminando con los Suecos y Daneses. De esto podemos inferir que compran una gran cantidad de items similares, o que compran los items más caros.
#
# ---

# %%
# Promedio por Invoice

df_retail_mean_invoice = df_retail_dmt_corr.groupby(["Country","InvoiceNo"], as_index = False).agg(
                            PaidInvoice = pd.NamedAgg("Paid","sum")
                        ).groupby(["Country"], as_index = False).agg(
                            PaidMean = pd.NamedAgg("PaidInvoice","mean")).sort_values(by=['PaidMean'], ascending=False)
df_retail_mean_invoice.head(5)
# Out:
#         Country     PaidMean
# 24  Netherlands  3052.573548
# 0     Australia  2467.344821
# 30    Singapore  2275.057500
# 20        Japan  1969.282632
# 21      Lebanon  1693.880000

# %%
fig, ax = plt.subplots()

bars = ax.bar(
    x=df_retail_mean_invoice.head(5)["Country"],
    height=df_retail_mean_invoice.head(5)["PaidMean"]
)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

bar_color = bars[0].get_facecolor()
for bar in bars:
  ax.text(
      bar.get_x() + bar.get_width() / 2,
      bar.get_height() + 0.3,
      round(bar.get_height(), 1),
      horizontalalignment='center',
      color=bar_color,
      weight='bold'
  )

ax.set_xlabel('Países', labelpad=15, color='#333333')
ax.set_ylabel('Gasto', labelpad=15, color='#333333')
ax.set_title('Gasto promedio por Invoice', pad=15, color='#333333',
             weight='bold')

fig.set_figheight(6)
fig.set_figwidth(8)
fig.tight_layout()

# %% [markdown]
# ---
#
# Al hacer un análisis por Invoice, se mantienen en los dos primeros lugares los Holandeses y Australianos, por lo que las compras de mayor valor las realizan estos países. No obstante los tres lugares siguientes los realizan desde Singapur, Japon y El Líbano, por lo que podemos deducir que estos países realizan compras con muchos items distintos al no aparecer en el ranking anterior.
#
# ---

# %%
# Promedio por día

df_retail_mean_day = df_retail_dmt_corr.groupby(["Country","OnlyDate"], as_index = False).agg(
                            PaidDay = pd.NamedAgg("Paid","sum")
                        ).groupby(["Country"], as_index = False).agg(
                            PaidMean = pd.NamedAgg("PaidDay","mean")).sort_values(by=['PaidMean'], ascending=False)
df_retail_mean_day.head(5)
# Out:
#            Country      PaidMean
# 36  United Kingdom  28625.737748
# 24     Netherlands   4506.180000
# 0        Australia   3213.286279
# 30       Singapore   2275.057500
# 20           Japan   2078.687222

# %%
fig, ax = plt.subplots()

bars = ax.bar(
    x=df_retail_mean_day.head(5)["Country"],
    height=df_retail_mean_day.head(5)["PaidMean"]
)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

bar_color = bars[0].get_facecolor()
for bar in bars:
  ax.text(
      bar.get_x() + bar.get_width() / 2,
      bar.get_height() + 0.3,
      round(bar.get_height(), 1),
      horizontalalignment='center',
      color=bar_color,
      weight='bold'
  )

ax.set_xlabel('Países', labelpad=15, color='#333333')
ax.set_ylabel('Gasto', labelpad=15, color='#333333')
ax.set_title('Gasto promedio por Día', pad=15, color='#333333',
             weight='bold')

fig.set_figheight(6)
fig.set_figwidth(8)
fig.tight_layout()

# %% [markdown]
# ---
#
# Por último, al hacer un análisis de gasto promedio al día, entra Reino Unido al primero lugar, y el supuesto es que la tienda se encuentra en este país, por lo que hay muchisimas más compras diarias nacionales que no son de gran gasto, pero que en suma aportan mucho más ingreso que el resto de los países a la tienda.
#
# ---

# %%
# Total de regalos

df_gift["Quantity"].sum()
# Out:
# 15280

# %% [markdown]
# ---
#
# Podemos ver que se regalaron 15.280 artículos, ahora veamos cuantos se regalaron por mes.
#
# ---

# %%
# Regalos por mes

df_gift["CorrectedDatetime"] = pd.to_datetime(df_gift["InvoiceDate"])
df_gift["WeekDay"] = df_gift["CorrectedDatetime"].dt.day_name()
df_gift["MonthNumber"] = df_gift["CorrectedDatetime"].dt.month
df_gift["Month"] = df_gift["CorrectedDatetime"].dt.month_name()
df_gift["Year"] = df_gift["CorrectedDatetime"].dt.year
df_gift["YearMonth"] = df_gift["Month"] + "-" + df_gift["Year"].apply(lambda x: str(x)) 
df_month_gift = df_gift.groupby(["YearMonth","MonthNumber","Year"], as_index = False).agg(
                    TotalGifts = pd.NamedAgg("Quantity","sum")
                ).sort_values(by = ["Year","MonthNumber"])
df_month_gift
# Out:
#          YearMonth  MonthNumber  Year  TotalGifts
# 2    December-2010           12  2010         268
# 5     January-2011            1  2011          57
# 4    February-2011            2  2011         105
# 8       March-2011            3  2011         109
# 0       April-2011            4  2011           4
# 9         May-2011            5  2011         195
# 7        June-2011            6  2011          56
# 6        July-2011            7  2011         770
# 1      August-2011            8  2011         861
# 12  September-2011            9  2011           1
# 11    October-2011           10  2011           7
# 10   November-2011           11  2011       12835
# 3    December-2011           12  2011          12

# %%
fig, ax = plt.subplots()

bars = ax.bar(
    x=df_month_gift["YearMonth"],
    height=df_month_gift["TotalGifts"]
)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

bar_color = bars[0].get_facecolor()
for bar in bars:
  ax.text(
      bar.get_x() + bar.get_width() / 2,
      bar.get_height() + 0.3,
      round(bar.get_height(), 1),
      horizontalalignment='center',
      color=bar_color,
      weight='bold'
  )

ax.set_xlabel('Mes', labelpad=15, color='#333333')
ax.set_ylabel('Cantidad', labelpad=15, color='#333333')
ax.set_title('Regalos mensuales hechos por la tienda', pad=15, color='#333333',
             weight='bold')

ax.tick_params(labelrotation=45)

fig.set_figheight(7)
fig.set_figwidth(12)
fig.tight_layout()

# %% [markdown]
# ### Segunda parte
#
# Utilizando SegmentationData.csv y obtener la solución de cluster jerárquico para k = 4 y con ella:
#  - Poner nombre a los 4 clusters
#  - Realizar crosstab (con MBA y Choice)
#  - Calcular el test de chi-cuadrado (pearson) para los crosstab (MBA y Choice) con el fin de responder si existe relación entre las variables. ( alfa = 0.05) (no incorporar corrección de Yates)

# %%
# Librerias

import scipy.cluster.hierarchy as shc

# Métodos

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from scipy.stats import chi2_contingency

# %%
# Lectura del dataframe

df_segment = pd.read_csv("https://raw.githubusercontent.com/patriciomalleag/Proyectos_Analisis_Varios/master/DS_Module_4/Homework_1/SegmentationData.csv")

# %%
# Dimensión del dataframe

df_segment.shape
# Out:
# (73, 9)

# %%
# Primeros 5 elementos

df_segment.head()
# Out:
#    ID  Trendy  Styling  Reliability  Sportiness  Performance  Comfort  MBA  \
# 0   1      10       20           35           5           20       10  MBA
# 1   2      25        5           25           5           25       15  MBA
# 2   3      10       20           30          10           10       20  MBA
# 3   4      10       15           30          10           20       15  MBA
# 4   5      20       10           40           1           14       15  MBA
#
#      Choice
# 0     Lexus
# 1       BMW
# 2     Lexus
# 3       BMW
# 4  Mercedes

# %%
# Información de los datos

df_segment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           73 non-null     int64
#  1   Trendy       73 non-null     int64
#  2   Styling      73 non-null     int64
#  3   Reliability  73 non-null     int64
#  4   Sportiness   73 non-null     int64
#  5   Performance  73 non-null     int64
#  6   Comfort      73 non-null     int64
#  7   MBA          73 non-null     object
#  8   Choice       73 non-null     object
# dtypes: int64(7), object(2)
# memory usage: 5.3+ KB

# %%
# Estadísticos descriptivos

df_segment.describe()
# Out:
#               ID     Trendy    Styling  Reliability  Sportiness  Performance  \
# count  73.000000  73.000000  73.000000    73.000000   73.000000    73.000000
# mean   37.000000  14.835616  16.917808    22.479452   10.931507    19.424658
# std    21.217131   7.065200   6.217702     7.090897    5.097191     6.732834
# min     1.000000   1.000000   5.000000    10.000000    1.000000     1.000000
# 25%    19.000000  10.000000  13.000000    19.000000    8.000000    15.000000
# 50%    37.000000  15.000000  15.000000    20.000000   10.000000    20.000000
# 75%    55.000000  20.000000  20.000000    25.000000   15.000000    25.000000
# max    73.000000  30.000000  30.000000    40.000000   25.000000    40.000000
#
#          Comfort
# count  73.000000
# mean   15.410959
# std     4.887159
# min     4.000000
# 25%    10.000000
# 50%    15.000000
# 75%    20.000000
# max    30.000000

# %% [markdown]
# ---
#
# A priori los datos se ven limpios y sin outliers, por lo que aplicaremos los métodos directamente al dataframe. En primer lugar crearemos un dataframe solamente con los campos numéricos y estadarizamos.
#
# ---

# %%
# Estandarización datos numéricos

scaler = StandardScaler()
std_list = scaler.fit_transform(df_segment[["Trendy","Styling","Reliability","Sportiness","Performance"]])
df_segment_std = pd.DataFrame(std_list,columns=["Trendy","Styling","Reliability","Sportiness","Performance"])

# %%
# Primeros 5 registros

df_segment_std.head(5)
# Out:
#      Trendy   Styling  Reliability  Sportiness  Performance
# 0 -0.689164  0.499143     1.777941   -1.171735     0.086045
# 1  1.448611 -1.930019     0.357922   -1.171735     0.833813
# 2 -0.689164  0.499143     1.067932   -0.184014    -1.409493
# 3 -0.689164 -0.310578     1.067932   -0.184014     0.086045
# 4  0.736019 -1.120299     2.487950   -1.961912    -0.811278

# %%
# Ploteamos el dendograma

plt.figure(figsize=(10, 7))  
plt.title("Dendrogram")  
dend = shc.dendrogram(shc.linkage(df_segment_std, method='ward'))
plt.axhline(y=7, color='r', linestyle='--')
plt.show()

# %%
# Clusterización

cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')  
cluster_list = cluster.fit_predict(df_segment_std)

# %%
# Columna de cluster

df_segment_std["cluster"] = cluster_list
df_segment_std
# Out:
#       Trendy   Styling  Reliability  Sportiness  Performance  cluster
# 0  -0.689164  0.499143     1.777941   -1.171735     0.086045        1
# 1   1.448611 -1.930019     0.357922   -1.171735     0.833813        1
# 2  -0.689164  0.499143     1.067932   -0.184014    -1.409493        1
# 3  -0.689164 -0.310578     1.067932   -0.184014     0.086045        2
# 4   0.736019 -1.120299     2.487950   -1.961912    -0.811278        1
# ..       ...       ...          ...         ...          ...      ...
# 68  0.450983  0.175255    -0.494089    0.803707    -0.362617        2
# 69  0.736019  1.308864    -1.062096   -0.184014    -0.661724        0
# 70  0.023428 -0.310578    -0.352087   -0.184014     0.833813        2
# 71 -0.689164  2.118585    -0.352087   -1.171735     0.086045        0
# 72 -1.686792  0.499143     0.357922   -1.764367     3.077120        3
#
# [73 rows x 6 columns]

# %%
# Promedios por cluster

df_segment_mean = df_segment_std.groupby(["cluster"]).agg(
                    TrendyMean = pd.NamedAgg("Trendy","mean"),
                    StylingMean = pd.NamedAgg("Styling","mean"),
                    ReliabilityMean = pd.NamedAgg("Reliability","mean"),
                    SportinessMean = pd.NamedAgg("Sportiness","mean"),
                    PerformanceMean = pd.NamedAgg("Performance","mean"))
df_segment_mean
# Out:
#          TrendyMean  StylingMean  ReliabilityMean  SportinessMean  \
# cluster
# 0          0.767002     0.837113        -0.518785        0.116597
# 1         -0.389875    -0.585883         1.635939       -1.230998
# 2         -0.119091    -0.428355        -0.167054        0.498412
# 3         -1.401756     0.105850         0.155063       -0.974191
#
#          PerformanceMean
# cluster
# 0              -0.824283
# 1              -0.003688
# 2               0.217471
# 3               1.688406

# %% [markdown]
# ---
#
# Los nombres de los clusters serán los siguientes
#
# 0 - Generacion Z
# 1 - Salfate
# 2 - Electrolito
# 3 - Optimus Prime
#
# ---

# %%
# Creamos la columna ClusterName

def name_cluster(x):
    if x==0:
        return "Generación Z"
    elif x==1:
        return "Salfate"
    elif x==2:
        return "Electrolito"
    else:
        return "Optimus Prime"
    
df_segment_std["ClusterName"] = df_segment_std["cluster"].apply(lambda x: name_cluster(x))

# %%
# Contamos la cantidad de elementos por cluster

df_segment_std.groupby(["ClusterName"]).agg(
                    Quantity = pd.NamedAgg("ClusterName","count"))
# Out:
#                Quantity
# ClusterName
# Electrolito          33
# Generación Z         23
# Optimus Prime         7
# Salfate              10

# %% [markdown]
# ---
#
# Ahora que tenemos los clusters definidos, realizaremos un crostabb con las columnas *MBA* y *Choice* de la tabla original.
#
# ---

# %%
# Crosstab de los cluster con la columna MBA

df_crosstab_mba = pd.crosstab(df_segment_std["ClusterName"],df_segment["MBA"], margins=False)
df_crosstab_mba
# Out:
# MBA            MBA  Undergrad
# ClusterName
# Electrolito      9         24
# Generación Z     5         18
# Optimus Prime    3          4
# Salfate          7          3

# %%
# Crosstab de los cluster con la columna Choice

df_crosstab_choice = pd.crosstab(df_segment_std["ClusterName"],df_segment["Choice"], margins=False)
df_crosstab_choice
# Out:
# Choice         BMW  Lexus  Mercedes
# ClusterName
# Electrolito     15      7        11
# Generación Z    10      7         6
# Optimus Prime    2      4         1
# Salfate          5      4         1

# %% [markdown]
# ---
#
# Ahora que tenemos los dataframes correspondientes a los crosstab, procedemos a realizar los test de Pearson para ver si existe relación entre las variables.
#
# ---

# %%
chi2_contingency(df_crosstab_mba)
# Out:
# (8.323414506965973,
#  0.03977984254516871,
#  3,
#  array([[10.84931507, 22.15068493],
#         [ 7.56164384, 15.43835616],
#         [ 2.30136986,  4.69863014],
#         [ 3.28767123,  6.71232877]]))

# %%
chi2_contingency(df_crosstab_choice)
# Out:
# (5.403357643457368,
#  0.4932133295683204,
#  6,
#  array([[14.46575342,  9.94520548,  8.5890411 ],
#         [10.08219178,  6.93150685,  5.98630137],
#         [ 3.06849315,  2.10958904,  1.82191781],
#         [ 4.38356164,  3.01369863,  2.60273973]]))

# %% [markdown]
# ---
#
# Para el primer caso, el valor p es de 0.03977984254516871, por lo cual existe evidencia para rechazar la hipotesis nula de que las variables son independientes con una confianza mayor al 96%. No obstante para la variable *Choice* el valor p es 0.4932133295683204, por lo que no podemos rechazar la hipotesis nula y suponer una dependencia entre el Cluster y la elección.
#
# ---
